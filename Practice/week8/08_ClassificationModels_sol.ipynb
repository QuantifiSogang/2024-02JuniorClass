# %% [markdown]
# ## Practice 1
#
# 준비된 `Credit_data_risk.csv`는 성별, 직업, 자택소유 여부 등 경제적 능력에 대한 feature와 신용 리스크 label을 담고 있는 데이터다. label의 기준은 다음과 같다
#
# - 신용이 좋은 사람 : good
# - 신용이 나쁜 사람 : bad
#
# Logit과 Probit 모형을 사용해서 아래 데이터에 대해 분류를 해 보자

# %%
import numpy as np
import pandas as pd

# %%
credit = pd.read_csv('./Credit_data_risk.csv', index_col = 0)
credit=credit.dropna()
credit.reset_index(inplace=True, drop=True)
credit
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     22  female    2     own          little         moderate           5951
# 1     45    male    2    free          little           little           7882
# 2     53    male    2    free          little           little           4870
# 3     35    male    3    rent          little         moderate           6948
# 4     28    male    3     own          little         moderate           5234
# ..   ...     ...  ...     ...             ...              ...            ...
# 517   48    male    1     own          little         moderate           1743
# 518   30    male    3     own          little           little           3959
# 519   40    male    3     own          little           little           3857
# 520   23    male    2    free          little           little           1845
# 521   27    male    2     own        moderate         moderate           4576
#
#      Duration              Purpose  Risk
# 0          48             radio/TV   bad
# 1          42  furniture/equipment  good
# 2          24                  car   bad
# 3          36                  car  good
# 4          30                  car   bad
# ..        ...                  ...   ...
# 517        24             radio/TV  good
# 518        36  furniture/equipment  good
# 519        30                  car  good
# 520        45             radio/TV   bad
# 521        45                  car  good
#
# [522 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler

# 데이터 전처리

SS=StandardScaler()
credit_part=credit[['Age', 'Credit amount', 'Duration']]

credit_std=SS.fit_transform(credit_part)
credit_std=pd.DataFrame(credit_std, columns=credit_part.columns)
job_df=pd.get_dummies(credit.Job, dtype=int)
job_df.columns=['job1', 'job2', 'job3', 'job4']
credit_std=pd.concat([credit_std, job_df], axis=1)
credit_std
# Out:
#           Age  Credit amount  Duration  job1  job2  job3  job4
# 0   -1.094447       0.913171  2.139356     0     0     1     0
# 1    0.858575       1.573037  1.657897     0     0     1     0
# 2    1.537887       0.543768  0.213521     0     0     1     0
# 3    0.009435       1.253868  1.176438     0     0     0     1
# 4   -0.584963       0.668155  0.694979     0     0     0     1
# ..        ...            ...       ...   ...   ...   ...   ...
# 517  1.113317      -0.524799  0.213521     0     1     0     0
# 518 -0.415135       0.232459  1.176438     0     0     0     1
# 519  0.434005       0.197603  0.694979     0     0     0     1
# 520 -1.009533      -0.489943  1.898626     0     0     1     0
# 521 -0.669877       0.443302  1.898626     0     0     1     0
#
# [522 rows x 7 columns]

# %%
credit_obj=credit.select_dtypes(object)
credit_obj=credit_obj.iloc[:, :-1]
obj_df=pd.DataFrame()

for column in credit_obj.columns:
    temp_df=pd.get_dummies(credit_obj.loc[:, column])
    obj_df=pd.concat([obj_df, temp_df], axis=1)

credit.Risk=credit.Risk.replace({'good' : 1, 'bad' : 0})
obj_df=obj_df.astype(int)
credit_fin=pd.concat([credit_std, obj_df, credit.Risk], axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(19,12))

for i in range(len(credit_fin.columns)):
    plt.subplot(7,4,i+1)
    sns.kdeplot(credit_fin[credit_fin.columns[i]])
    plt.title(credit_fin.columns[i])

plt.show()
# Out:
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kumb2\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

X = credit_fin.drop(['Risk'], axis = 1)
X = sm.add_constant(X)
y = credit_fin['Risk']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
logit_model = sm.Logit(y_train, X_train)

result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.579481
#          Iterations 13
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   Risk   No. Observations:                  365
# Model:                          Logit   Df Residuals:                      343
# Method:                           MLE   Df Model:                           21
# Date:                Fri, 22 Nov 2024   Pseudo R-squ.:                  0.1547
# Time:                        17:43:58   Log-Likelihood:                -211.51
# converged:                       True   LL-Null:                       -250.22
# Covariance Type:            nonrobust   LLR p-value:                 2.174e-08
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.2773   6.21e+06   4.46e-08      1.000   -1.22e+07    1.22e+07
# Age                     0.0584      0.132      0.442      0.658      -0.200       0.317
# Credit amount          -0.0701      0.172     -0.408      0.683      -0.407       0.266
# Duration               -0.7480      0.167     -4.466      0.000      -1.076      -0.420
# job1                    0.5386        nan        nan        nan         nan         nan
# job2                   -0.1719        nan        nan        nan         nan         nan
# job3                    0.0317        nan        nan        nan         nan         nan
# job4                   -0.1210        nan        nan        nan         nan         nan
# female                 -0.0179   7.06e+06  -2.54e-09      1.000   -1.38e+07    1.38e+07
# male                    0.2952   7.41e+06   3.98e-08      1.000   -1.45e+07    1.45e+07
# free                    0.2831        nan        nan        nan         nan         nan
# own                     0.1440        nan        nan        nan         nan         nan
# rent                   -0.1498        nan        nan        nan         nan         nan
# little                 -0.6754    2.2e+07  -3.08e-08      1.000    -4.3e+07     4.3e+07
# moderate               -0.4844   2.14e+07  -2.26e-08      1.000    -4.2e+07     4.2e+07
# quite rich              0.0032    2.2e+07   1.47e-10      1.000    -4.3e+07     4.3e+07
# rich                    1.4338   2.22e+07   6.47e-08      1.000   -4.34e+07    4.34e+07
# little                 -0.2121   2.07e+07  -1.03e-08      1.000   -4.05e+07    4.05e+07
# moderate               -0.0192   2.07e+07  -9.32e-10      1.000   -4.05e+07    4.05e+07
# rich                    0.5086   2.07e+07   2.46e-08      1.000   -4.05e+07    4.05e+07
# business                0.6031   2.38e+07   2.54e-08      1.000   -4.66e+07    4.66e+07
# car                     0.2816   2.38e+07   1.18e-08      1.000   -4.66e+07    4.66e+07
# domestic appliances     0.0878   2.38e+07    3.7e-09      1.000   -4.66e+07    4.66e+07
# education              -2.6470   2.38e+07  -1.11e-07      1.000   -4.66e+07    4.66e+07
# furniture/equipment     0.3564   2.38e+07    1.5e-08      1.000   -4.66e+07    4.66e+07
# radio/TV                0.5959   2.38e+07   2.51e-08      1.000   -4.66e+07    4.66e+07
# repairs                 0.6918   2.38e+07   2.91e-08      1.000   -4.66e+07    4.66e+07
# vacation/others         0.3077   2.38e+07   1.29e-08      1.000   -4.66e+07    4.66e+07
# =======================================================================================

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
y_pred = (result.predict(X_test) > 0.5).astype(int)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.45      0.48        71
#            1       0.59      0.66      0.63        86
#
#     accuracy                           0.57       157
#    macro avg       0.56      0.56      0.56       157
# weighted avg       0.56      0.57      0.56       157

# %% [markdown]
# `sklearn.metrics`내의 `classification_report`를 통해 간단한 metric을 볼 수 있다.
#
# 의사결정에서 비용이 어떤 것이 큰지에 따라 선호되는 metric이 달라질 수 있다. 이는 프로젝트의 성격에 따라 취사선택할 수 있다

# %% [markdown]
# Model이 얼마나 잘 분류했는지를 보는 과정 중 가장 유명한 것은 **혼동 행렬(Confusion Matrix)** 를 보는 것이다. 혼동 행렬은 아래와 같이 나타낸다
#
# <center>
#
# |                     | Predicted positive | Predicted negative |
# |:-------------------:|:------------------:|:------------------:|
# | **Actual positive** |   True Positive    |   False negative   |
# | **Actual negative** |   False positive   |   True Negative    |
#
# </center>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (3, 3))
sns.heatmap(cm, annot = True, fmt = 'd', cbar = False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix', fontsize = 12, fontfamily = 'Serif')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, classification_report, roc_curve

y_pred_prob = result.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.figure(figsize = (6, 4))
plt.plot(fpr, tpr, label = 'Logit Model', color = 'navy', alpha = 0.8)
plt.plot([0, 1], [0, 1], 'k:')
plt.grid(False)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Logit Model', fontsize = 12, fontfamily = 'Serif')
plt.legend()
plt.show()

# %% [markdown]
# probit model의 경우를 살펴보자

# %%
probit_model = sm.Probit(y_train, X_train)

result = probit_model.fit()
print(result.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.581173
#          Iterations: 35
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                   Risk   No. Observations:                  365
# Model:                         Probit   Df Residuals:                      343
# Method:                           MLE   Df Model:                           21
# Date:                Fri, 22 Nov 2024   Pseudo R-squ.:                  0.1522
# Time:                        17:43:58   Log-Likelihood:                -212.13
# converged:                      False   LL-Null:                       -250.22
# Covariance Type:            nonrobust   LLR p-value:                 3.478e-08
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1734        nan        nan        nan         nan         nan
# Age                     0.0440      0.079      0.555      0.579      -0.111       0.199
# Credit amount          -0.0453      0.103     -0.438      0.661      -0.248       0.157
# Duration               -0.4411      0.098     -4.482      0.000      -0.634      -0.248
# job1                    0.3146        nan        nan        nan         nan         nan
# job2                   -0.1004        nan        nan        nan         nan         nan
# job3                    0.0139        nan        nan        nan         nan         nan
# job4                   -0.0547        nan        nan        nan         nan         nan
# female                 -0.0121   5.24e+06  -2.32e-09      1.000   -1.03e+07    1.03e+07
# male                    0.1855   6.55e+06   2.83e-08      1.000   -1.28e+07    1.28e+07
# free                    0.1779        nan        nan        nan         nan         nan
# own                     0.0903        nan        nan        nan         nan         nan
# rent                   -0.0948        nan        nan        nan         nan         nan
# little                 -0.3929   7.58e+06  -5.18e-08      1.000   -1.49e+07    1.49e+07
# moderate               -0.2870   4.89e+06  -5.87e-08      1.000   -9.59e+06    9.59e+06
# quite rich              0.0205   7.36e+06   2.78e-09      1.000   -1.44e+07    1.44e+07
# rich                    0.8327   5.46e+06   1.52e-07      1.000   -1.07e+07    1.07e+07
# little                 -0.1161        nan        nan        nan         nan         nan
# moderate                0.0021        nan        nan        nan         nan         nan
# rich                    0.2874        nan        nan        nan         nan         nan
# business                0.3268        nan        nan        nan         nan         nan
# car                     0.1340        nan        nan        nan         nan         nan
# domestic appliances     0.0143        nan        nan        nan         nan         nan
# education              -1.3461        nan        nan        nan         nan         nan
# furniture/equipment     0.1868        nan        nan        nan         nan         nan
# radio/TV                0.3310        nan        nan        nan         nan         nan
# repairs                 0.3775        nan        nan        nan         nan         nan
# vacation/others         0.1491        nan        nan        nan         nan         nan
# =======================================================================================
# c:\Users\kumb2\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
y_pred = (result.predict(X_test) > 0.5).astype(int)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.45      0.48        71
#            1       0.59      0.66      0.63        86
#
#     accuracy                           0.57       157
#    macro avg       0.56      0.56      0.56       157
# weighted avg       0.56      0.57      0.56       157

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (3, 3))
sns.heatmap(cm, annot = True, fmt = 'd', cbar = False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix', fontsize = 12, fontfamily = 'Serif')
plt.show()

# %%
y_pred_prob = result.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.figure(figsize = (6, 4))
plt.plot(fpr, tpr, label = 'Probit Model', color = 'darkorange', alpha = 0.8)
plt.plot([0, 1], [0, 1], 'k:')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Probit Model', fontsize = 12, fontfamily = 'Serif')
plt.grid(False)
plt.legend()
plt.show()

# %% [markdown]
# ## practice 2
#
# practice 1의 분류를 Gaussian Naive Bayes Model에 대해 추정해 보자

# %%
from sklearn.naive_bayes import GaussianNB

X_train = X_train.drop('const', axis = 1)
X_test = X_test.drop('const', axis = 1)

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.535031847133758

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.45      0.47        71
#            1       0.57      0.60      0.59        86
#
#     accuracy                           0.54       157
#    macro avg       0.53      0.53      0.53       157
# weighted avg       0.53      0.54      0.53       157

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (3, 3))
sns.heatmap(cm, annot = True, fmt = 'd', cbar = False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix', fontsize = 12, fontfamily = 'Serif')
plt.show()

# %%
from sklearn.metrics import auc
y_prob = nb_model.fit(X_train, y_train).predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize = (6, 4))
plt.plot(fpr, tpr, label = 'Naive Bayes (area = {:.2f})'.format(roc_auc), color = 'purple', alpha = 0.8)
plt.plot([0, 1], [0, 1], 'k:')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Gaussian Naive Bayes', fontsize = 12, fontfamily = 'Serif')
plt.grid(False)
plt.legend()
plt.show()

# %% [markdown]
# ## practice 3
#
# practice 1의 분류 모형을 SVM으로 추정해 보자. 여기서 kernel은 선형을 가정하고, C = 0.1으로 지정한다. ROC curve를 그리기 위해 `probaility = True`로 지정한다

# %%
from sklearn.svm import SVC
svc = SVC(kernel = 'linear',
          C = 0.1, 
          probability = True,
          random_state = 42)
svc.fit(X_train, y_train)
# Out:
# SVC(C=0.1, kernel='linear', probability=True, random_state=42)

# %%
y_prob = svc.predict_proba(X_test)[:, 1]
y_pred = svc.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.5605095541401274

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.37      0.43        71
#            1       0.58      0.72      0.64        86
#
#     accuracy                           0.56       157
#    macro avg       0.55      0.54      0.54       157
# weighted avg       0.55      0.56      0.55       157

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (3, 3))
sns.heatmap(cm, annot = True, fmt = 'd', cbar = False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix', fontsize = 12, fontfamily = 'Serif')
plt.show()

# %%
y_prob = svc.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize = (6, 4))
plt.plot(fpr, tpr, label = 'SVM (area = {:.2f})'.format(roc_auc), color = 'navy', alpha = 0.8)
plt.plot([0, 1], [0, 1], 'k:')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Support Vector Machine', fontsize = 12, fontfamily = 'Serif')
plt.grid(False)
plt.legend()
plt.show()

# %% [markdown]
# ## practice 4
#
# practice 1의 분류 모형을 가져와서 Decision Tree모형으로 분류를 진행해 보자. 여기서 criterion은 entropy, random_state는 42를 지정하도록 한다

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion = 'entropy',
                              random_state = 42)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
y_prob = tree.predict_proba(X_test)[:, 1]
y_pred = tree.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.5605095541401274

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.52        71
#            1       0.60      0.58      0.59        86
#
#     accuracy                           0.56       157
#    macro avg       0.56      0.56      0.56       157
# weighted avg       0.56      0.56      0.56       157

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (3, 3))
sns.heatmap(cm, annot = True, fmt = 'd', cbar = False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix', fontsize = 12, fontfamily = 'Serif')
plt.show()

# %%
y_prob = tree.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize = (6, 4))
plt.plot(fpr, tpr, label = 'Decision Tree (area = {:.2f})'.format(roc_auc), color = 'green', alpha = 0.8)
plt.plot([0, 1], [0, 1], 'k:')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Decision Tree', fontsize = 12, fontfamily = 'Serif')
plt.grid(False)
plt.legend()
plt.show()
